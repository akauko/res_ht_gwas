# %% [markdown]
# # Run regenie: Resistant hypertension replication
#
# This script preprocesses genotype data and runs GWAS with SNP data. We replicate analysis performed earlier with FinnGen data. Both analysis steps will be carried out with SNP data as was done in FinnGen.
#
# Phenotypes have been created by script **create_ukbb_pheno_resht.Rmd**
#
# **Variable definitions**
#
# * Genotypes:
#   - 22418, chip data (GRCh37) for regenie step 1
#   - 21008, imputed data, Genomics England (GRCh38) for regenie step2
# * Phenotypes:
#   - resht_fg: Number of hypertensive medication classes $\geq$ 4 and hypertension
#   - resht_ukb: Number of medication classes $\geq$ 3, Systolic BP  $\geq$ 140 or diastolic BP  $\geq$ 90 and hypertension
#   - resht_both: resht_fg or resht_ukbb
#   - Control for all variables: One hypertensive medication class and hypertension
#  * Covariates:
#    - 21003, Age when attended assessment centre (Baseline characteristics)
#    - 22001, Sex (Genotypes)
#    - 22009, Genetic principal components (Genotypes)
#
# **Run variables**

# %%
name="resht"
pheno_file_dir="/data"
geno_file_dir="/data/genotype"
regenie_out_dir="/data/regenie"

geno_var="ukb22418"
geno_in="/mnt/project/data/lifted_geno_in/${geno_var}_c*.???"  #[1-9]*"
bed_base="${geno_var}_c1_22_merged" #_c10_b0_v2_GRCh38_full_analysis_set_plus_decoy_hla.fam  

geno2_var="ukb21008"
geno2_indir="/Bulk/Imputation/Imputation\ from\ genotype\ \(GEL\)"

pheno_in="resht_pheno.tsv"
pheno_cols="resht_fg,resht_ukb,resht_both"
covar_cols="p21003,p22001,p22009_a1,p22009_a2,p22009_a3,p22009_a4,p22009_a5,p22009_a6,p22009_a7,p22009_a8,p22009_a9,p22009_a10"

instance="mem1_ssd1_v2_x16"

# %% [markdown]
# ## Lift over
#
# The chip data is in the GRCh37 reference, while imputed data is in the GRCh37 reference. We will lift over the chip data by liftover_plink_beds pipeline: https://github.com/dnanexus-rnd/liftover_plink_beds\n". The protocol is described in the file `run_liftover.ipynb`.

# %% [markdown]
# ## Preprocess genotype data
#
# ### Chip data
#
# #### Merge chromosome data

# %%
run_merge="cp ${geno_in} . ;\
           ls *.bed | sed -e 's/.bed//g' > files_to_merge.txt;\
           plink --merge-list files_to_merge.txt \
                 --make-bed \
                 --chr 1-22 \
                 --allow-extra-chr \
                 --out ${bed_base};\
           rm files_to_merge.txt;"
             
dx run swiss-army-knife \
           -icmd="${run_merge}" \
           --tag="Step0" \
           --instance-type ${instance} \
           --destination="${geno_file_dir}/" \
           --brief --yes --wait
# Out:
# job-Gb74yZQJFFQbp5xgzJxgzg3q

# %% [markdown]
# #### Filter genotypes

# %%
run_plink_qc="plink2 --bfile ${bed_base} \
                     --keep ${pheno_in}  \
                     --autosome \
                     --maf 0.01 --mac 20 --geno 0.1 \
                     --hwe 1e-15 --mind 0.1 \
                     --write-snplist \
                     --write-samples \
                     --no-id-header \
                     --out geno_qc_pass"

dx run swiss-army-knife \
   -iin="${geno_file_dir}/${bed_base}.bed" \
   -iin="${geno_file_dir}/${bed_base}.bim" \
   -iin="${geno_file_dir}/${bed_base}.fam" \
   -iin="${pheno_file_dir}/${pheno_in}" \
   -icmd="${run_plink_qc}" \
   --tag="Step0" \
   --instance-type ${instance} \
   --destination="${geno_file_dir}/" \
   --brief --yes --wait
# Out:
# job-Gb952BjJFFQbv07q75Kxv3G2

# %% [markdown]
# ## Run Regenie
#
# We will run with similar settings as in FinnGen.
#
# ### Regenie step 1: Fit model

# %%
run_regenie_step1="regenie \
  --step 1 \
  --bt \
  --bed ${bed_base} \
  --extract geno_qc_pass.snplist \
  --phenoFile ${pheno_in} \
  --phenoColList '${pheno_cols}' \
  --covarFile ${pheno_in} \
  --covarColList '${covar_cols}' \
  --bsize 1000 \
  --lowmem \
  --gz \
  --threads 16 \
  --out ${name}_step1"

dx run swiss-army-knife \
   -iin="${geno_file_dir}/${bed_base}.bed" \
   -iin="${geno_file_dir}/${bed_base}.bim" \
   -iin="${geno_file_dir}/${bed_base}.fam" \
   -iin="${geno_file_dir}/geno_qc_pass.snplist" \
   -iin="${pheno_file_dir}/${pheno_in}" \
   -icmd="${run_regenie_step1}" \
   --tag="Step1" --instance-type ${instance} \
   --destination="${regenie_out_dir}/" \
   --brief --yes --wait
# Out:
# job-Gb95PzQJFFQvQbjpBy194G96

# %% [markdown]
# ### Regenie step 2: Association testing
#
# We perform association testing for SNP data.

# %%
for chr in {1..22}; do

    run_regenie_step2="regenie \
      --step 2 \
      --bgen ${geno2_var}_c${chr}_b0_v1.bgen \
      --sample ${geno2_var}_c${chr}_b0_v1.sample \
      --ref-first \
      --phenoFile ${pheno_in} \
      --phenoColList '${pheno_cols}' \
      --covarFile ${pheno_in} \
      --covarColList '${covar_cols}' \
      --pred ${name}_step1_pred.list \
      --bt \
      --firth  \
      --firth-se\
      --approx \
      --bsize 400 \
      --pThresh 0.05 \
      --threads 16 \
      --gz \
      --out assoc_c${chr}"

    dx run swiss-army-knife \
       -iin="${geno2_indir}/${geno2_var}_c${chr}_b0_v1.bgen" \
       -iin="${geno2_indir}/${geno2_var}_c${chr}_b0_v1.sample" \
       -iin="${geno_file_dir}/geno_qc_pass.snplist" \
       -iin="${pheno_file_dir}/${pheno_in}" \
       -iin="${regenie_out_dir}/${name}_step1_pred.list" \
       -iin="${regenie_out_dir}/${name}_step1_1.loco.gz" \
       -iin="${regenie_out_dir}/${name}_step1_2.loco.gz" \
       -iin="${regenie_out_dir}/${name}_step1_3.loco.gz" \
       -icmd="${run_regenie_step2}" \
       --tag="Step2" --instance-type ${instance} \
       --destination="${regenie_out_dir}/" \
       --brief --yes

done

# %%
#Wait until all chromosomes have been run 
# for chr in {1..22}; do
#   until [ -f /mnt/project${regenie_out_dir}/assoc_c${chr}.log ]
#   do
#     sleep 120s  #Check after every 2 min
#  done  
#done
#sleep 120s #Wait 2 min... log f

# %% [markdown]
# ## Post processing

# %% [markdown]
# ### Merge

# %%
#Perhaps if I make script out of this, I could make this work with SAK..

dx download -f ${regenie_out_dir}/assoc_c*.regenie.gz
for pheno in ${pheno_cols//,/ }; do
    results_out="assoc.${pheno}.regenie"
    #Title
    zcat  assoc_c*_${pheno}.regenie.gz | head -1 | sed 's/ /\t/g' > ${results_out}
    #Merge
    for chr in {1..22}; do
        zcat assoc_c${chr}_${pheno}.regenie.gz | tail -n+2 | sed 's/ /\t/g' >>  ${results_out}
    done
    #Calculate P from LOG10P column, remove values without P and INFO<0.3
    R -e "df<-as.data.frame(data.table::fread(\"${results_out}\"));\
          df['P']<-10^(-df['LOG10P']);\
          df<-subset(df,LOG10P!='NA');\
          df<-subset(df,INFO>0.3);\
          data.table::fwrite(df,paste0(\"${results_out}\",\".gz\"), sep='\t', na='NA', quote=F)"
    dx upload "${results_out}.gz" --path "${regenie_out_dir}/${results_out}.gz"

done   
rm assoc*regenie*
# Out:
# [===========================================================>] Completed 117,307,715 of 117,307,715 bytes (100%) /opt/notebooks/assoc_c3_resht_fg.regenie.gzz
# [===========================================================>] Completed 129,313,601 of 129,313,601 bytes (100%) /opt/notebooks/assoc_c3_resht_both.regenie.gzz
# [===========================================================>] Completed 127,883,693 of 127,883,693 bytes (100%) /opt/notebooks/assoc_c3_resht_ukb.regenie.gzz
# [===========================================================>] Completed 153,116,496 of 153,116,496 bytes (100%) /opt/notebooks/assoc_c2_resht_ukb.regenie.gzz
# [===========================================================>] Completed 140,331,833 of 140,331,833 bytes (100%) /opt/notebooks/assoc_c2_resht_fg.regenie.gzz
# [===========================================================>] Completed 154,806,847 of 154,806,847 bytes (100%) /opt/notebooks/assoc_c2_resht_both.regenie.gzz
# [===========================================================>] Completed 104,267,686 of 104,267,686 bytes (100%) /opt/notebooks/assoc_c7_resht_ukb.regenie.gzz
# [===========================================================>] Completed 95,652,969 of 95,652,969 bytes (100%) /opt/notebooks/assoc_c7_resht_fg.regenie.gzz
# [===========================================================>] Completed 105,414,270 of 105,414,270 bytes (100%) /opt/notebooks/assoc_c7_resht_both.regenie.gzz
# [===========================================================>] Completed 141,842,399 of 141,842,399 bytes (100%) /opt/notebooks/assoc_c1_resht_ukb.regenie.gzz
# [===========================================================>] Completed 143,427,719 of 143,427,719 bytes (100%) /opt/notebooks/assoc_c1_resht_both.regenie.gzz
# [===========================================================>] Completed 130,040,603 of 130,040,603 bytes (100%) /opt/notebooks/assoc_c1_resht_fg.regenie.gzz
# [===========================================================>] Completed 80,291,912 of 80,291,912 bytes (100%) /opt/notebooks/assoc_c11_resht_fg.regenie.gzz
# [===========================================================>] Completed 88,487,229 of 88,487,229 bytes (100%) /opt/notebooks/assoc_c11_resht_both.regenie.gzz
# [===========================================================>] Completed 87,498,860 of 87,498,860 bytes (100%) /opt/notebooks/assoc_c11_resht_ukb.regenie.gzz
# [===========================================================>] Completed 125,702,080 of 125,702,080 bytes (100%) /opt/notebooks/assoc_c4_resht_both.regenie.gzz
# [===========================================================>] Completed 124,313,148 of 124,313,148 bytes (100%) /opt/notebooks/assoc_c4_resht_ukb.regenie.gzz
# [===========================================================>] Completed 114,175,127 of 114,175,127 bytes (100%) /opt/notebooks/assoc_c4_resht_fg.regenie.gzz
# [===========================================================>] Completed 111,344,883 of 111,344,883 bytes (100%) /opt/notebooks/assoc_c6_resht_both.regenie.gzz
# [===========================================================>] Completed 101,231,120 of 101,231,120 bytes (100%) /opt/notebooks/assoc_c6_resht_fg.regenie.gzz
# [===========================================================>] Completed 110,143,016 of 110,143,016 bytes (100%) /opt/notebooks/assoc_c6_resht_ukb.regenie.gzz
# [===========================================================>] Completed 114,802,426 of 114,802,426 bytes (100%) /opt/notebooks/assoc_c5_resht_ukb.regenie.gzz
# [===========================================================>] Completed 116,056,464 of 116,056,464 bytes (100%) /opt/notebooks/assoc_c5_resht_both.regenie.gzz
# [===========================================================>] Completed 105,302,356 of 105,302,356 bytes (100%) /opt/notebooks/assoc_c5_resht_fg.regenie.gzz
# [===========================================================>] Completed 98,700,178 of 98,700,178 bytes (100%) /opt/notebooks/assoc_c8_resht_ukb.regenie.gzz
# [===========================================================>] Completed 99,828,393 of 99,828,393 bytes (100%) /opt/notebooks/assoc_c8_resht_both.regenie.gzz
# [===========================================================>] Completed 90,506,076 of 90,506,076 bytes (100%) /opt/notebooks/assoc_c8_resht_fg.regenie.gzz
# [===========================================================>] Completed 78,723,237 of 78,723,237 bytes (100%) /opt/notebooks/assoc_c9_resht_both.regenie.gzz
# [===========================================================>] Completed 77,867,224 of 77,867,224 bytes (100%) /opt/notebooks/assoc_c9_resht_ukb.regenie.gzz
# [===========================================================>] Completed 71,496,116 of 71,496,116 bytes (100%) /opt/notebooks/assoc_c9_resht_fg.regenie.gzz
# [===========================================================>] Completed 89,133,425 of 89,133,425 bytes (100%) /opt/notebooks/assoc_c10_resht_both.regenie.gzz
# [===========================================================>] Completed 80,939,300 of 80,939,300 bytes (100%) /opt/notebooks/assoc_c10_resht_fg.regenie.gzz
# [===========================================================>] Completed 88,154,537 of 88,154,537 bytes (100%) /opt/notebooks/assoc_c10_resht_ukb.regenie.gzz
# [===========================================================>] Completed 77,640,416 of 77,640,416 bytes (100%) /opt/notebooks/assoc_c12_resht_fg.regenie.gzz
# [===========================================================>] Completed 84,634,588 of 84,634,588 bytes (100%) /opt/notebooks/assoc_c12_resht_ukb.regenie.gzz
# [===========================================================>] Completed 85,598,091 of 85,598,091 bytes (100%) /opt/notebooks/assoc_c12_resht_both.regenie.gzz
# [===========================================================>] Completed 59,518,703 of 59,518,703 bytes (100%) /opt/notebooks/assoc_c16_resht_both.regenie.gzz
# [===========================================================>] Completed 58,858,544 of 58,858,544 bytes (100%) /opt/notebooks/assoc_c16_resht_ukb.regenie.gzz
# [===========================================================>] Completed 53,941,660 of 53,941,660 bytes (100%) /opt/notebooks/assoc_c16_resht_fg.regenie.gzz
# [===========================================================>] Completed 62,875,464 of 62,875,464 bytes (100%) /opt/notebooks/assoc_c13_resht_ukb.regenie.gzz
# [===========================================================>] Completed 63,573,095 of 63,573,095 bytes (100%) /opt/notebooks/assoc_c13_resht_both.regenie.gzz
# [===========================================================>] Completed 57,742,406 of 57,742,406 bytes (100%) /opt/notebooks/assoc_c13_resht_fg.regenie.gzz
# [===========================================================>] Completed 57,323,874 of 57,323,874 bytes (100%) /opt/notebooks/assoc_c14_resht_ukb.regenie.gzz
# [===========================================================>] Completed 57,970,136 of 57,970,136 bytes (100%) /opt/notebooks/assoc_c14_resht_both.regenie.gzz
# [===========================================================>] Completed 52,631,740 of 52,631,740 bytes (100%) /opt/notebooks/assoc_c14_resht_fg.regenie.gzz
# [===========================================================>] Completed 48,178,176 of 48,178,176 bytes (100%) /opt/notebooks/assoc_c17_resht_fg.regenie.gzz
# [===========================================================>] Completed 52,559,029 of 52,559,029 bytes (100%) /opt/notebooks/assoc_c17_resht_ukb.regenie.gzz
# [===========================================================>] Completed 53,151,926 of 53,151,926 bytes (100%) /opt/notebooks/assoc_c17_resht_both.regenie.gzz
# [===========================================================>] Completed 52,019,847 of 52,019,847 bytes (100%) /opt/notebooks/assoc_c15_resht_ukb.regenie.gzz
# [===========================================================>] Completed 52,584,452 of 52,584,452 bytes (100%) /opt/notebooks/assoc_c15_resht_both.regenie.gzz
# [===========================================================>] Completed 47,721,512 of 47,721,512 bytes (100%) /opt/notebooks/assoc_c15_resht_fg.regenie.gzz
# [===========================================================>] Completed 50,023,428 of 50,023,428 bytes (100%) /opt/notebooks/assoc_c18_resht_both.regenie.gzz
# [===========================================================>] Completed 45,504,833 of 45,504,833 bytes (100%) /opt/notebooks/assoc_c18_resht_fg.regenie.gzz
# [===========================================================>] Completed 49,487,422 of 49,487,422 bytes (100%) /opt/notebooks/assoc_c18_resht_ukb.regenie.gzz
# [===========================================================>] Completed 41,846,351 of 41,846,351 bytes (100%) /opt/notebooks/assoc_c19_resht_both.regenie.gzz
# [===========================================================>] Completed 38,038,872 of 38,038,872 bytes (100%) /opt/notebooks/assoc_c19_resht_fg.regenie.gzz
# [===========================================================>] Completed 41,391,302 of 41,391,302 bytes (100%) /opt/notebooks/assoc_c19_resht_ukb.regenie.gzz
# [===========================================================>] Completed 41,838,094 of 41,838,094 bytes (100%) /opt/notebooks/assoc_c20_resht_both.regenie.gzz
# [===========================================================>] Completed 41,391,486 of 41,391,486 bytes (100%) /opt/notebooks/assoc_c20_resht_ukb.regenie.gzz
# [===========================================================>] Completed 37,977,295 of 37,977,295 bytes (100%) /opt/notebooks/assoc_c20_resht_fg.regenie.gzz
# [===========================================================>] Completed 23,345,308 of 23,345,308 bytes (100%) /opt/notebooks/assoc_c21_resht_ukb.regenie.gzz
# [===========================================================>] Completed 23,586,588 of 23,586,588 bytes (100%) /opt/notebooks/assoc_c21_resht_both.regenie.gzz
# [===========================================================>] Completed 21,491,076 of 21,491,076 bytes (100%) /opt/notebooks/assoc_c21_resht_fg.regenie.gzz
# [===========================================================>] Completed 25,148,786 of 25,148,786 bytes (100%) /opt/notebooks/assoc_c22_resht_ukb.regenie.gzz
# [===========================================================>] Completed 25,429,603 of 25,429,603 bytes (100%) /opt/notebooks/assoc_c22_resht_both.regenie.gzz
# [===========================================================>] Completed 23,081,051 of 23,081,051 bytes (100%) /opt/notebooks/assoc_c22_resht_fg.regenie.gzz
#
# gzip: stdout: Broken pipe
#
# R version 4.2.2 (2022-10-31) -- "Innocent and Trusting"
# Copyright (C) 2022 The R Foundation for Statistical Computing
# Platform: x86_64-pc-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.
#
# > df<-as.data.frame(data.table::fread("assoc.resht_fg.regenie"));          df['P']<-10^(-df['LOG10P']);          df<-subset(df,LOG10P!='NA');          df<-subset(df,INFO>0.3);          data.table::fwrite(df,paste0("assoc.resht_fg.regenie",".gz"), sep='\t', na='NA', quote=F)
# >
# >
# [===========================================================>] Uploaded 2,062,552,170 of 2,062,552,170 bytes (100%) assoc.resht_fg.regenie.gz
# ID                          file-GbBKk8QJFFQpvY1p7bykQXyz
# Class                       file
# Project                     project-GZ62xgQJFFQXbyFk1ZFJkFz0
# Folder                      /data/regenie
# Name                        assoc.resht_fg.regenie.gz
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Wed Nov 15 16:06:58 2023
# Created by                  anirka
#  via the job                job-GbBJ008JFFQzxGF3XXPbJ440
# Last modified               Wed Nov 15 16:07:04 2023
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
#
# gzip: stdout: Broken pipe
#
# R version 4.2.2 (2022-10-31) -- "Innocent and Trusting"
# Copyright (C) 2022 The R Foundation for Statistical Computing
# Platform: x86_64-pc-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.
#
# > df<-as.data.frame(data.table::fread("assoc.resht_ukb.regenie"));          df['P']<-10^(-df['LOG10P']);          df<-subset(df,LOG10P!='NA');          df<-subset(df,INFO>0.3);          data.table::fwrite(df,paste0("assoc.resht_ukb.regenie",".gz"), sep='\t', na='NA', quote=F)
# >
# >
# [===========================================================>] Uploaded 2,242,810,892 of 2,242,810,892 bytes (100%) assoc.resht_ukb.regenie.gz
# ID                          file-GbBKv1jJFFQqvV3K9225gjPg
# Class                       file
# Project                     project-GZ62xgQJFFQXbyFk1ZFJkFz0
# Folder                      /data/regenie
# Name                        assoc.resht_ukb.regenie.gz
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Wed Nov 15 16:12:55 2023
# Created by                  anirka
#  via the job                job-GbBJ008JFFQzxGF3XXPbJ440
# Last modified               Wed Nov 15 16:13:00 2023
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
#
# gzip: stdout: Broken pipe
#
# R version 4.2.2 (2022-10-31) -- "Innocent and Trusting"
# Copyright (C) 2022 The R Foundation for Statistical Computing
# Platform: x86_64-pc-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.
#
# > df<-as.data.frame(data.table::fread("assoc.resht_both.regenie"));          df['P']<-10^(-df['LOG10P']);          df<-subset(df,LOG10P!='NA');          df<-subset(df,INFO>0.3);          data.table::fwrite(df,paste0("assoc.resht_both.regenie",".gz"), sep='\t', na='NA', quote=F)
# >
# >
# [===========================================================>] Uploaded 2,267,139,554 of 2,267,139,554 bytes (100%) assoc.resht_both.regenie.gz
# ID                          file-GbBKyv0JFFQf44k8KG7jBYqx
# Class                       file
# Project                     project-GZ62xgQJFFQXbyFk1ZFJkFz0
# Folder                      /data/regenie
# Name                        assoc.resht_both.regenie.gz
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Wed Nov 15 16:18:56 2023
# Created by                  anirka
#  via the job                job-GbBJ008JFFQzxGF3XXPbJ440
# Last modified               Wed Nov 15 16:19:01 2023
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"

# %% [markdown]
# ### Draw manhattan and qq plots

# %%
#This could be run with SAK

dx download -f scripts/draw_manhattan.R
dx download -f ${regenie_out_dir}/assoc.*.regenie.gz
#Draw manhattan plots
for pheno in ${pheno_cols//,/ }; do
   Rscript draw_manhattan.R assoc.${pheno}.regenie.gz ${pheno}
done
dx upload *.png --path ${regenie_out_dir}/
# Out:
# [===========================================================>] Completed 834 of 834 bytes (100%) /opt/notebooks/draw_manhattan.R.R
# [===========================================================>] Completed 2,267,139,554 of 2,267,139,554 bytes (100%) /opt/notebooks/assoc.resht_both.regenie.gzz
# [===========================================================>] Completed 2,242,810,892 of 2,242,810,892 bytes (100%) /opt/notebooks/assoc.resht_ukb.regenie.gzz
# [===========================================================>] Completed 2,062,552,170 of 2,062,552,170 bytes (100%) /opt/notebooks/assoc.resht_fg.regenie.gzz
# Loading required package: data.table
# Loading required package: dplyr
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: qqman
#
# For example usage please run: vignette('qqman')
#
# Citation appreciated but not required:
# Turner, (2018). qqman: an R package for visualizing GWAS results using Q-Q and manhattan plots. Journal of Open Source Software, 3(25), 731, https://doi.org/10.21105/joss.00731.
#
# Loading required package: R.utils
# Loading required package: R.oo
# Loading required package: R.methodsS3
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
# R.oo v1.25.0 (2022-06-12 02:20:02 UTC) successfully loaded. See ?R.oo for help.
#
# Attaching package: ‘R.oo’
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
# R.utils v2.12.2 (2022-11-11 22:00:03 UTC) successfully loaded. See ?R.utils for help.
#
# Attaching package: ‘R.utils’
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, warnings
#
# data.table      dplyr      qqman    R.utils
#       TRUE       TRUE       TRUE       TRUE
# null device
#           1
# null device
#           1
# Loading required package: data.table
# Loading required package: dplyr
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: qqman
#
# For example usage please run: vignette('qqman')
#
# Citation appreciated but not required:
# Turner, (2018). qqman: an R package for visualizing GWAS results using Q-Q and manhattan plots. Journal of Open Source Software, 3(25), 731, https://doi.org/10.21105/joss.00731.
#
# Loading required package: R.utils
# Loading required package: R.oo
# Loading required package: R.methodsS3
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
# R.oo v1.25.0 (2022-06-12 02:20:02 UTC) successfully loaded. See ?R.oo for help.
#
# Attaching package: ‘R.oo’
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
# R.utils v2.12.2 (2022-11-11 22:00:03 UTC) successfully loaded. See ?R.utils for help.
#
# Attaching package: ‘R.utils’
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, warnings
#
# data.table      dplyr      qqman    R.utils
#       TRUE       TRUE       TRUE       TRUE
# null device
#           1
# null device
#           1
# Loading required package: data.table
# Loading required package: dplyr
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: qqman
#
# For example usage please run: vignette('qqman')
#
# Citation appreciated but not required:
# Turner, (2018). qqman: an R package for visualizing GWAS results using Q-Q and manhattan plots. Journal of Open Source Software, 3(25), 731, https://doi.org/10.21105/joss.00731.
#
# Loading required package: R.utils
# Loading required package: R.oo
# Loading required package: R.methodsS3
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
# R.oo v1.25.0 (2022-06-12 02:20:02 UTC) successfully loaded. See ?R.oo for help.
#
# Attaching package: ‘R.oo’
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
# R.utils v2.12.2 (2022-11-11 22:00:03 UTC) successfully loaded. See ?R.utils for help.
#
# Attaching package: ‘R.utils’
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, warnings
#
# data.table      dplyr      qqman    R.utils
#       TRUE       TRUE       TRUE       TRUE
# null device
#           1
